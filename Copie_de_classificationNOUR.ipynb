# %% [markdown]
# <a href="https://colab.research.google.com/github/BennourNour/tunisie_annonce_srapping-python-part2/blob/main/Copie_de_classificationNOUR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #importer les biliotheques

# %%
import numpy as np # bibliotheque de calcul vectoriel --> utilise nd_array comme structure de données
import pandas as pd #API interface entre le programmeur et les données --> utilise DATAFRAME comme structure de données
import matplotlib.pyplot as plt # bibliothéque standard de represntation graphique de PYTHON

# %% [markdown]
# #charger le dataset

# %%
cars=pd.read_csv('/content/Car details v3.csv')

# %%
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
cars.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
cars.tail(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 8118                  Hyundai i20 Magna  2013         380000      25000
# 8119        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120            Hyundai Santro Xing GLS  2008         120000     191000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
# 8126                    Tata Indigo CR4  2013         290000      25000
# 8127                    Tata Indigo CR4  2013         290000      25000
#
#         fuel seller_type transmission                 owner     mileage  \
# 8118  Petrol  Individual       Manual           First Owner   18.5 kmpl
# ...

# %%
type (cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
cars.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
cars.shape
# Out:
# (8128, 13)

# %%
oldest_year = cars['year'].min()

# %%
cars.loc [cars.year == cars.year.min()]
# Out:
#                           name  year  selling_price  km_driven    fuel  \
# 316  Mahindra Willys CJ 3B 4X4  1983         300000      10000  Diesel
#
#     seller_type transmission        owner mileage engine max_power torque  \
# 316  Individual       Manual  Third Owner     NaN    NaN       NaN    NaN
#
#      seats
# 316    NaN

# %%
cars.loc [cars.selling_price == cars.selling_price.max()]
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 170  Volvo XC90 T8 Excellence BSIV  2017       10000000      30000  Petrol
#
#     seller_type transmission        owner    mileage   engine max_power  \
# 170  Individual    Automatic  First Owner  42.0 kmpl  1969 CC   400 bhp
#
#              torque  seats
# 170  640Nm@ 1740rpm    4.0

# %%
def Brand (name):
  l=name.split()
  return l[0]

# %%
cars['Brand']=cars.name.apply(Brand)

# %%
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
def Model (name):
  l=name.split()
  return l[1]

# %%
cars['model']=cars.name.apply(Model)

# %%
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
cars.drop(['name','torque'],axis=1,inplace =True )

# %%
cars
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner     mileage   engine   max_power  seats    Brand  \
# ...

# %%
cars.isnull().sum()
# Out:
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# seats            221
# Brand              0
# model              0
# dtype: int64

# %%
cars.shape
# Out:
# (8128, 13)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8128 non-null   int64
#  1   selling_price  8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   object
#  8   engine         7907 non-null   object
#  9   max_power      7913 non-null   object
#  10  seats          7907 non-null   float64
#  11  Brand          8128 non-null   object
#  12  model          8128 non-null   object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
s='1248 CC'
l=s.split()
l
# Out:
# ['1248', 'CC']

# %%
def clean(var):
  try:
    l=var.split()
    return pd.to_numeric(l[0])
  except:
    return None

# %%
cars['engine']=cars.engine.apply(clean)
cars['max_power']=cars.max_power.apply(clean)
cars['mileage']=cars.mileage.apply(clean)

# %%
cars
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats    Brand   model
# ...

# %%
cars
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats    Brand   model
# ...

# %%
cars.isnull().sum()
# Out:
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        216
# seats            221
# Brand              0
# model              0
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, MinMaxScaler, StandardScaler
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %%
X,y = cars.drop('selling_price',axis=1), cars.selling_price

# %%
numerical_cols=X.select_dtypes(include=np.number).columns.tolist()
categorical_cols=X.select_dtypes(exclude=np.number).columns.tolist()
categorical_cols.pop(categorical_cols.index('owner'))
ordinal_cols=['owner']

# %%
numerical_pipeline=make_pipeline(KNNImputer(),StandardScaler())
